# %%
import unittest

# %%
class SimpleMath:
    def divide(self, numerator, denominator):
        if denominator == 0:
            raise ZeroDivisionError("Cannot divide by 0")
        return numerator/denominator

# %%
class SimpleMathTest(unittest.TestCase):
    def testThatZeroNumeratorReturnsZero(self):
        mathTest = SimpleMath()
        self.assertEqual(mathTest.divide(0,7),0)
        
    def testThatSmallerNumeratorReturnsDecimalValue(self):
        mathTest = SimpleMath()
        self.assertEqual(mathTest.divide(1,4),0.25)
        
    def testThatSmallerNumeratorReturnsRepeatingDecimalValue(self):
        mathTest = SimpleMath()
        self.assertAlmostEqual(mathTest.divide(1,7),0.143,3)
        
    def testThatZeroDenominatorThrowsException(self):
        mathTest = SimpleMath()
        with self.assertRaises(ZeroDivisionError):
            mathTest.divide(6,0)
        
if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.013s
#
# OK
